# %%
# Importing necessary libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
import seaborn as sns

# %%
# Reading the dataset

df=pd.read_excel("./Precision Property Insights.xlsx")

# %%
# Information of the dataset

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 23 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   cid               21613 non-null  int64
#  1   dayhours          21613 non-null  object
#  2   price             21613 non-null  int64
#  3   room_bed          21505 non-null  float64
#  4   room_bath         21505 non-null  float64
#  5   living_measure    21596 non-null  float64
#  6   lot_measure       21571 non-null  float64
#  7   ceil              21571 non-null  object
#  8   coast             21612 non-null  object
#  9   sight             21556 non-null  float64
#  10  condition         21556 non-null  object
#  11  quality           21612 non-null  float64
#  12  ceil_measure      21612 non-null  float64
#  13  basement          21612 non-null  float64
#  14  yr_built          21612 non-null  object
#  15  yr_renovated      21613 non-null  int64
#  16  zipcode           21613 non-null  int64
#  17  lat               21613 non-null  float64
#  18  long              21613 non-null  object
#  19  living_measure15  21447 non-null  float64
#  20  lot_measure15     21584 non-null  float64
#  21  furnished         21584 non-null  float64
#  22  total_area        21584 non-null  object
# dtypes: float64(12), int64(4), object(7)
# memory usage: 3.8+ MB

# %%
# Let's have a look at the first 5 values of the dataset
df.head()
# Out:
#           cid         dayhours   price  room_bed  room_bath  living_measure  \
# 0  3876100940  20150427T000000  600000       4.0       1.75          3050.0
# 1  3145600250  20150317T000000  190000       2.0       1.00           670.0
# 2  7129303070  20140820T000000  735000       4.0       2.75          3040.0
# 3  7338220280  20141010T000000  257000       3.0       2.50          1740.0
# 4  7950300670  20150218T000000  450000       2.0       1.00          1120.0
#
#    lot_measure ceil coast  sight  ... basement  yr_built  yr_renovated  \
# 0       9440.0    1     0    0.0  ...   1250.0      1966             0
# 1       3101.0    1     0    0.0  ...      0.0      1948             0
# 2       2415.0    2     1    4.0  ...      0.0      1966             0
# 3       3721.0    2     0    0.0  ...      0.0      2009             0
# 4       4590.0    1     0    0.0  ...      0.0      1924             0
#
#    zipcode      lat     long  living_measure15  lot_measure15 furnished  \
# 0    98034  47.7228 -122.183            2020.0         8660.0       0.0
# 1    98118  47.5546 -122.274            1660.0         4100.0       0.0
# 2    98118  47.5188 -122.256            2620.0         2433.0       0.0
# 3    98002  47.3363 -122.213            2030.0         3794.0       0.0
# 4    98118  47.5663 -122.285            1120.0         5100.0       0.0
#
#    total_area
# 0       12490
# 1        3771
# 2        5455
# 3        5461
# 4        5710
#
# [5 rows x 23 columns]

# %%
# Let's create a helper summary function

def summary(dataframe:pd.DataFrame)-> pd.DataFrame:
    '''
    Function to generate a summary of the dataframe including column names, data types, missing values, unique values, and examples of unique values.
    '''
    _data={
        "col_name":[],
        "dtype":[],
        "missing":[],
        "percentage of missing":[],
        "unique":[],
        "example_uniq_val":[]
    }
    cols=dataframe.columns.values
    rows=dataframe.shape[0]
    _data["col_name"].extend(cols)
    _data["dtype"].extend([str(dataframe[i].dtype) for i in cols])
    _data["missing"].extend([int(dataframe[i].isnull().sum()) for i in cols])
    _data["percentage of missing"].extend([dataframe[i].isnull().sum()/rows*100 for i in cols])
    _data["unique"].extend([len(dataframe[i].unique()) for i in cols])
    _data["example_uniq_val"].extend([dataframe[i].dropna().unique()[:3] for i in cols])

    return pd.DataFrame(_data)

# %%
summary(df)
# Out:
#             col_name    dtype  missing  percentage of missing  unique  \
# 0                cid    int64        0               0.000000   21436
# 1           dayhours   object        0               0.000000     372
# 2              price    int64        0               0.000000    3625
# 3           room_bed  float64      108               0.499699      14
# 4          room_bath  float64      108               0.499699      31
# 5     living_measure  float64       17               0.078656    1039
# 6        lot_measure  float64       42               0.194327    9766
# 7               ceil   object       42               0.194327       8
# 8              coast   object        1               0.004627       4
# 9              sight  float64       57               0.263730       6
# 10         condition   object       57               0.263730       7
# 11           quality  float64        1               0.004627      13
# 12      ceil_measure  float64        1               0.004627     947
# 13          basement  float64        1               0.004627     307
# 14          yr_built   object        1               0.004627     118
# 15      yr_renovated    int64        0               0.000000      70
# 16           zipcode    int64        0               0.000000      70
# 17               lat  float64        0               0.000000    5034
# 18              long   object        0               0.000000     753
# 19  living_measure15  float64      166               0.768056     775
# 20     lot_measure15  float64       29               0.134179    8683
# 21         furnished  float64       29               0.134179       3
# 22        total_area   object       29               0.134179   11146
#
#                                      example_uniq_val
# 0                [3876100940, 3145600250, 7129303070]
# 1   [20150427T000000, 20150317T000000, 20140820T00...
# 2                            [600000, 190000, 735000]
# 3                                     [4.0, 2.0, 3.0]
# 4                                   [1.75, 1.0, 2.75]
# 5                             [3050.0, 670.0, 3040.0]
# 6                            [9440.0, 3101.0, 2415.0]
# 7                                           [1, 2, 3]
# 8                                           [0, 1, $]
# 9                                     [0.0, 4.0, 2.0]
# 10                                          [3, 4, 5]
# 11                                    [8.0, 6.0, 7.0]
# 12                            [1800.0, 670.0, 3040.0]
# 13                              [1250.0, 0.0, 1320.0]
# 14                                 [1966, 1948, 2009]
# 15                                    [0, 1993, 2014]
# 16                              [98034, 98118, 98002]
# 17                        [47.7228, 47.5546, 47.5188]
# 18                     [-122.183, -122.274, -122.256]
# 19                           [2020.0, 1660.0, 2620.0]
# 20                           [8660.0, 4100.0, 2433.0]
# 21                                         [0.0, 1.0]
# 22                                [12490, 3771, 5455]

# %%
'''As per my observation, let's have a look at the columns.
We can drop the irrelevant columns before handling null values and this can be also be done after handling null values '''

# At first, we can drop the cid column

df=df.drop("cid",axis=1)

# %%
# Let's handle the missing values

missing_cols=df[[col for col in df.columns if df[col].isnull().sum()>0]].columns.values

# %%
# We now have the column names with missing values

missing_cols
# Out:
# array(['room_bed', 'room_bath', 'living_measure', 'lot_measure', 'ceil',
#        'coast', 'sight', 'condition', 'quality', 'ceil_measure',
#        'basement', 'yr_built', 'living_measure15', 'lot_measure15',
#        'furnished', 'total_area'], dtype=object)

# %% [markdown]
# <h3><i><span style="color:cyan">Handling columns sequentially</span></i></h3>

# %%
''' Let's make another helper function which will let us know the unique values,
the distribution of the column name and the number of missing values with it's datatype'''

def col_info_check(df:pd.DataFrame, col_name:str, scale=None):
    print(f"Missing value count: {df[col_name].isnull().sum()}")
    print(f"Unique values: {df[col_name].unique()}")
    print(f"dtype: {df[col_name].dtype}")

    if df[col_name].dtype!="object":
        plt.title(f"Distribution of '{col_name}'")
        sns.histplot(df, x=col_name, kde=True, bins=50)
        plt.xlabel(col_name)
        plt.ylabel("Count")
        if scale:
            plt.xticks(range(0, int(df[col_name].max()) + 1, scale))
        plt.xticks(rotation=45)
        plt.gca().xaxis.set_major_formatter(mticker.StrMethodFormatter('{x:,.0f}'))
        plt.show()

# %%
# room_bed

col_info_check(df, "room_bed", 2)
# Out:
# Missing value count: 108
# Unique values: [ 4.  2.  3.  1.  5.  6. nan  7. 10.  8.  0.  9. 33. 11.]
# dtype: float64

# %%
# As we can see, that the number of bedrooms are peaking with room sizes of 3-4 bedrooms and it also has outliers (assumption is >10 bedrooms)

# We can impute it with median or mode

df.loc[df["room_bed"].isnull(), "room_bed"]=df["room_bed"].mode().values[0]

# %%
df["room_bed"].unique()
# Out:
# array([ 4.,  2.,  3.,  1.,  5.,  6.,  7., 10.,  8.,  0.,  9., 33., 11.])

# %%
# room_bath

col_info_check(df, "room_bath")
# Out:
# Missing value count: 108
# Unique values: [1.75 1.   2.75 2.5  1.5  3.5  2.   2.25 3.   4.   3.25 3.75  nan 5.
#  0.75 5.5  4.25 4.5  4.75 8.   6.75 5.25 6.   0.   1.25 5.75 7.5  6.5
#  0.5  7.75 6.25]
# dtype: float64

# %%
# As we can see, that the room_bath is in decimals, which is not quite possible in the real world scenario. We're gonna round off these values

non_missing_idx=[index for index, item in enumerate(df["room_bath"].isnull()) if item==False]

for i in non_missing_idx:
    df.loc[i, "room_bath"]=np.round(df.loc[i, "room_bath"])

# %%
col_info_check(df, "room_bath")
# Out:
# Missing value count: 108
# Unique values: [ 2.  1.  3.  4. nan  5.  6.  8.  7.  0.]
# dtype: float64

# %%
# After visualing, we see that there is a peak of 2 bathrooms, with outliers (assumption >5 bathrooms)

# We can impute it with median or mode

df.loc[df["room_bath"].isnull(), "room_bath"]=df["room_bath"].median()

# %%
df["room_bath"].unique()
# Out:
# array([2., 1., 3., 4., 5., 6., 8., 7., 0.])

# %%
# living_measure and lot_measure

col_info_check(df, "living_measure")
# Out:
# Missing value count: 17
# Unique values: [3050.  670. 3040. ... 1405. 1295. 2253.]
# dtype: float64

# %%
df["living_measure"].head()
# Out:
# 0    3050.0
# 1     670.0
# 2    3040.0
# 3    1740.0
# 4    1120.0
# Name: living_measure, dtype: float64

# %%
df["lot_measure"].head()
# Out:
# 0    9440.0
# 1    3101.0
# 2    2415.0
# 3    3721.0
# 4    4590.0
# Name: lot_measure, dtype: float64

# %%
df["total_area"].head()
# Out:
# 0    12490
# 1     3771
# 2     5455
# 3     5461
# 4     5710
# Name: total_area, dtype: object

# %%
# From above we notice, that total area is actually the sum of living_measure and lot_measure
# We'll check the details for the total area and and drop the other 2 columns as they will be highly correlated to the total_area

col_info_check(df, "total_area")
# Out:
# Missing value count: 29
# Unique values: [12490 3771 5455 ... 16111 63597 38122]
# dtype: object

# %%
# As total area is an object type, let's check for any faulty value as well

set([i for i in df["total_area"] if not isinstance(i,(float, int))])
# Out:
# {'$'}

# %%
# We have '$' as a faulty value, let's replace it with nan values

cols_idx_with_faulty_values=[index for index, item in enumerate(df["total_area"]) if item=="$"]

for i in cols_idx_with_faulty_values:
    df.loc[i, "total_area"]=np.nan

# %%
df["total_area"]=df["total_area"].astype("float")

# %%
df["total_area"].isnull().sum()
# Out:
# np.int64(68)

# %%
missing_idx=[index for index, item in enumerate(df["total_area"].isnull()) if item==True]

# %%
for i in missing_idx:
    df.loc[i, "total_area"]=df.loc[i, "living_measure"]+df.loc[i, "lot_measure"]

# %%
pd.DataFrame({
    "total_area":df["total_area"][missing_idx],
    "sum_living_lot_measure":df["living_measure"][missing_idx]+df["lot_measure"][missing_idx],
    "living_measure":df["living_measure"][missing_idx],
    "lot_measure":df["lot_measure"][missing_idx],
})
# Out:
#        total_area  sum_living_lot_measure  living_measure  lot_measure
# 128        9852.0                  9852.0          1830.0       8022.0
# 402        8820.0                  8820.0          2700.0       6120.0
# 455        5825.0                  5825.0          1700.0       4125.0
# 578       11685.0                 11685.0          2160.0       9525.0
# 843       11730.0                 11730.0          2530.0       9200.0
# ...           ...                     ...             ...          ...
# 19981      7130.0                  7130.0          1250.0       5880.0
# 20199     15153.0                 15153.0          2860.0      12293.0
# 20251     11460.0                 11460.0          1140.0      10320.0
# 21152     10396.0                 10396.0          3490.0       6906.0
# 21172      7890.0                  7890.0          3390.0       4500.0
#
# [68 rows x 4 columns]

# %%
# Now we're going to drop living and lot measure

# df=df.drop(["living_measure", "lot_measure"], axis=1)

# %%
missing_cols
# Out:
# array(['room_bed', 'room_bath', 'living_measure', 'lot_measure', 'ceil',
#        'coast', 'sight', 'condition', 'quality', 'ceil_measure',
#        'basement', 'yr_built', 'living_measure15', 'lot_measure15',
#        'furnished', 'total_area'], dtype=object)

# %%
# ceil

col_info_check(df, "ceil")
# Out:
# Missing value count: 42
# Unique values: [1 2 3 1.5 2.5 '$' nan 3.5]
# dtype: object

# %%
# Replacing faulty values with nan

faulty_idx=[index for index, item in enumerate(df["ceil"]) if item=="$"]

# %%
for i in faulty_idx:
    df.loc[i, "ceil"]=np.nan

# %%
col_info_check(df, "ceil")
# Out:
# Missing value count: 72
# Unique values: [1 2 3 1.5 2.5 nan 3.5]
# dtype: object

# %%
# As we can see, ceil can be interpreted as number of floors

non_missing_idx=[index for index, item in enumerate(df["ceil"].isnull()) if item==False]

# %%
for i in non_missing_idx:
    df.loc[i, "ceil"]=np.round(df.loc[i, "ceil"])

# %%
df["ceil"]=df["ceil"].astype("float")

# %%
col_info_check(df, "ceil",1)
# Out:
# Missing value count: 72
# Unique values: [ 1.  2.  3. nan  4.]
# dtype: float64

# %%
# As per my observation, there are 2 strong points, ceil 1 and 2
# The best imputation strategy would be to impute it with mode

df.loc[df["ceil"].isnull(), "ceil"]=df["ceil"].mode().values[0]

# %%
df["ceil"].isnull().sum()
# Out:
# np.int64(0)

# %%
# ceil_measure

col_info_check(df, "ceil_measure")
# Out:
# Missing value count: 1
# Unique values: [1800.  670. 3040. 1740. 1120. 1610. 1140. 3360. 3100. 1460. 3310. 1520.
#  2450. 1390.  910. 1450. 1040. 1200. 1570. 1940. 2170. 1750. 1430. 1220.
#  2790.  720. 1180.  950. 2470. 3220.  900. 1420. 1870. 2920. 1100. 1440.
#  2360. 3000. 1130. 2156. 1170. 1300. 1340. 2820. 2290. 1070.  800. 1550.
#  2200. 1230. 2305. 1270. 1540. 1890. 1060. 1620. 2670. 1980. 1760. 1150.
#  1470. 1160. 2270. 3500. 1950.  750. 3290. 3240. 1320. 1769. 1790.  830.
#  1290. 1010. 1910. 2110. 2460. 3550. 1330. 1280. 1480. 2040. 2150. 3140.
#  1370. 1400. 2740. 2020. 2530. 1260. 3370.  870. 1500. 1240. 1810. 2190.
#   890.  630. 1410. 2180. 3460. 4160. 1830. 1380. 1530. 2610. 3180.  880.
#  1690. 1930. 1190. 1600. 2240. 2210. 2750. 3440. 1000. 5110. 1757. 1900.
#  1050. 3480.  740. 3820. 1990.  970. 1490. 3080. 2390. 2680. 2100.  620.
#  7320. 2050.  860. 6050. 1920. 2580. 1210.  810. 1680. 1080. 1560.  700.
#   840. 1030. 4140. 2590. 1250. 1660.  710.  730. 1970. 3950. 1590. 1310.
#  1580. 2990. 1770. 1350.  780. 2070. 2400. 2120. 2250. 1020. 2420. 3960.
#  4000.  590. 2090. 3600. 2660. 2080. 1650.  980. 3190. 3110. 2380. 1640.
#  2440. 1670. 2570. 1360.  960. 4360. 3350. 3300. 3320.  820. 1730. 2330.
#  2000.  640. 2340. 2641. 4480. 2410. 2507. 2540. 1090. 3720. 1824. 2550.
#  2840. 3630. 3380. 1840. 4320. 3150.  460. 3270. 3330. 2230. 4850. 1820.
#  3700. 2168. 3010. 2910.  770.  990. 1780. 1700.  920. 2430. 3520. 2650.
#  2370. 3410. 3200. 4060. 3260. 1110. 3060. 2960. 2130. 1720. 3030. 2280.
#  2890. 2870. 2600. 2710. 4280. 2930. 5190. 2800. 3800. 3810. 4230. 3840.
#   940. 2830. 2510. 1630. 2480. 3540. 2160. 1510. 2350. 2320. 2720. 4620.
#  2770. 1960. 2475. 3900. 4390. 2520. 3750.  765. 2630.  660.  930. 4560.
#  3470. 2690. 4790. 2760.  850. 3860. 1656. 3400. 3590. 2640.  790. 1850.
#  3730.  680. 2780. 3020. 1710. 4960. 1088. 2700. 1392. 2860. 2900. 2810.
#  3430. 1880. 2030. 3620. 3510. 3340.  760. 1983. 2730. 5020. 2310. 2300.
#  4115. 4760. 3070. 4370. 6720. 4430. 3090. 2260. 8570. 3910. 3223. 2010.
#  3830. 2220. 2849. 5400. 1678. 2155. 1676. 3680. 3390. 5080. 3660. 3570.
#  1646. 4820.  550. 3780. 2653. 4720. 1766. 2940. 1995. 2669. 2732. 1833.
#  2140. 2850. 1860. 2560. 2060. 3530. 2714. 1095. 3250. 4270. 1502. 2980.
#  1255. 3420. 2403. 3222. 4180. 2196. 2620. 3160. 3670. 3650. 4750. 2692.
#  4040. 2811. 4150. 2025. 6430. 3206. 4110. 3230. 2632. 1413. 3120.  580.
#  4930. 2970. 1651. 4083. 1479. 4290. 2950. 4210. 2166. 3170.  570. 2803.
#   600. 3610. 2031. 4590. 1679. 4130.  480. 4440. 3280. 1419. 5330. 2885.
#  1414. 1654. 2303. 1785. 3580. 3450. 2708. 2891. 2500. 2244.  610. 1564.
#  2880. 5130. 3560. 3595. 4070.  470. 3940. 3605. 2286. 3690. 4120. 3980.
#  4570. 5480. 3485. 1363. 2490. 3640. 2153. 2242. 3790. 3130. 3880. 4170.
#  2689. 1715. 1802. 5230. 2789. 4810. 4350. 4260. 1763. 4660. 1159. 1608.
#  1427. 4890. 2544. 1494. 1889. 4010. 2744. 3210.  290. 4470. 1864. 2623.
#  4100. 2718. 4610. 5180. 1002. 3336. 7880. 4030. 1961.  490. 2398. 3930.
#  2755. 1552. 1578. 1934. 3181. 4410. 4250. 1765. 4740. 4090. 1347. 2393.
#  3065. 2009.  690. 3050. 6660. 3504.  650. 1987. 3770. 2375. 4475. 4900.
#  3172. 5000. 1752. 2185. 2283. 2434. 4950. 4300. 1852. 1358. 1584. 2738.
#  1116. 4310. 2502.  806. 3920. 4340. 5440. 2807. 5060. 2496. 1352. 2298.
#  2095. 4500. 1175.  520. 3870. 4190. 2734. 1322. 4080. 5430. 3970. 3266.
#  3569. 2267. 1131. 2201. 1954. 1313. 4380. 3006. 3361. 1778.  560. 1408.
#  3276. 4020. 1355. 1652. 4050. 3850. 2432. 6370. 1689. 3740. 1122.  798.
#  1129. 1808. 2659. 1867. 2683.  998. 2154. 4400. 5320. 3490. 1794.  370.
#  2655. 2301. 1996. 5300. 2864. 2029. 1981. 2414. 1008. 2612. 2726. 7420.
#  4670. 2052. 4240. 4580. 1509. 1914. 3760. 3028. 2815. 1239. 1975. 5050.
#  3845. 4540. 2105. 5240. 1728. 2481. 1232. 1341.  530. 4220. 3281. 1658.
#  4910. 7850. 9410. 2093. 1899. 1657. 3526. 5990. 3831. 1048. 3710. 1068.
#  1747. 2575. 1384. 1982. 3695. 5370. 1544. 3488. 6110. 4640. 1288. 2979.
#  4460. 1912. 2007. 1798. 4700. 3316. 2555. 2906. 1847.  809. 1604. 2441.
#  2217. 1453. 2026. 2223. 2671. 1812. 5710. 4840.  390. 4780. 2038. 2074.
#  4490. 2961. 2075. 2927. 6350. 2229. 4860. 4980. 1256. 3890. 2828. 5830.
#  2456. 3855. 2437. 2495. 3087. 1677. 3990. 2425. 2588. 3192. 1076. 2483.
#  1446. 2675. 8860. 5250. 2478. 7680. 4073. 2145. 5153. 3004.  430. 1264.
#  2529. 3906. 1165. 3828. 2643. 6220. 2796.  500. 1553. 1275. 1405. 2587.
#  2406. 1072. 2423. 2245.  380. 2658. 4200. 5760. 2424. 3045. 1788. 4225.
#  6070. 3135. 4830. 2966.  540.  893. 1144. 1444. 1295.  440. 2678. 4510.
#  2701. 1746. 3284. 2019. 2519. 6200. 3148. 2783. 4770. 5844. 1484. 1333.
#  5403. 3905. 2846. 2473. 5160. 1605. 2192. 2533. 1964. 2517. 1315. 2795.
#  5550. 5070. 1108. 2578. 2299. 2905. 1615. 1936. 2056. 1481. 2163. 4065.
#   963. 1092. 2024. 2538. 1572. 4940.  420. 1613. 6420. 3527. 3216. 4630.
#  2584. 5040. 2044. 2134. 2506. 1946. 1643. 3859. 1381. 2716. 1845.  384.
#  2497. 3056. 2594. 1767. 2542. 2216. 1061. 2341. 5450. 2963. 3202. 1329.
#  1216. 1491. 1397.  992. 1741. 2099. 2665. 2208. 2557. 2313.  902. 1606.
#   995. 3691. 1489. 1078. 3078. 3362. 3597. 2415. 2798. 1782. 5140. 5220.
#  4420. 5584. 1435. 2577. 2015. 5670. 1212. 1087. 1984. 3154. 4800. 1921.
#  2793. 5010. 1611. 2181. 2518. 2311. 2656. 2452. 5610. 6640.  944. 2238.
#  1536. 1296. 1714. 4600. 2092. 2014. 2932. 1805. 2413. 2115. 6380. 1876.
#  5980. 2329. 2601. 3555. 2165. 1976. 1094. 1556. 4330. 3002. 2174. 2782.
#  2717. 2568.  844.  962. 1764. 1248. 3236. 1451. 3745. 2068. 3274. 3052.
#  2547. 2233. 3915. 2198. 4450. 5090. 2844. 5530. 1084. 1904. 2531. 3118.
#  6530. 2628. 1425. 1628. 1571. 3136. 2331. 5310.  901. 3674. 1834. 1396.
#  6120. 6085. 2356. 6090. 1422. 3001. 6290. 2835. 5490.  833. 8020. 3265.
#   410. 1726.  988. 3064. 1528. 2598. 2448. 2395.  828. 1811.  866.   nan
#   894. 2382. 4285. 1595. 1463. 4133. 2064. 5770. 4870. 1105. 2253.]
# dtype: float64

# %%
# We can impute it with median or mode or we can check that, is there a relation between living measure and ceil

idx=202
df["ceil_measure"][idx], df["ceil"][idx], df["living_measure"][idx], df["living_measure"][idx]/df["ceil"][idx]
# Out:
# (np.float64(1290.0), np.float64(1.0), np.float64(2550.0), np.float64(2550.0))

# %%
df.loc[df["ceil_measure"].isnull(), "ceil_measure"]=df["ceil_measure"].median()

# %%
df["ceil_measure"].isnull().sum()
# Out:
# np.int64(0)

# %%
# basement

col_info_check(df, "basement", 250)
# Out:
# Missing value count: 1
# Unique values: [1250.    0. 1320. 1000.  480.  610. 1050.  700.  430.  560.  250.  670.
#   570.  290.  600.  680.  380.   50. 1020.  690. 1010.  530. 1370. 1040.
#   790.  910.  820. 1850.  500.  760.  960.  340.  800.  580. 1600. 1680.
#   900.  420.  450.  200.  240.  950. 1590. 1220. 1500.  710.   80.  140.
#  1260.  860.  890.  280.  440.  880.  220. 1650.  630.  780.  810.  300.
#   720.  470.  150. 1180. 1060.  120.  660.  400. 1100. 1780.  640. 1170.
#  1890.  130.  550.  360.  940.  650. 2730.  870.  730. 1350. 1530. 1540.
#   620. 1080. 1900.  770.  520.  920. 1110.  830. 1420.  980.  190.  330.
#   350.  740. 1570.  990. 1390.  260.  540. 1300.  265. 1120.  460.  370.
#  1830. 1140.  270.  145.  510.  750. 1710.  930. 1870. 1200.  310.  850.
#   506.  970. 1070. 1450.  840.   90. 3500. 1380. 1090. 1280. 1240. 3480.
#  1210. 1690.   60. 1800. 2400.  180. 4820.  110. 1030. 2060.  143. 1400.
#   100. 1270. 2040. 1360. 1740.  590. 1150.   40. 1990. 1340. 1700.  160.
#  1290. 1190. 1630.  946. 1230. 1430. 2600.  390. 1620.  410. 1950. 1160.
#  1135.  320.  210. 1460.  170. 1490. 1330. 1760.  207. 2300. 1410. 2090.
#  1810. 1660. 1940. 3260. 1640.  894. 1440. 2200. 1130. 2010. 1790.  490.
#  1550. 1560.  230.   70.  276.  417.  652. 2000.  283. 1580. 1670. 1310.
#  1720. 2390. 2100.  374.  414. 2620.  176. 1910.  515. 1730. 1820. 2080.
#   666. 1480.  861. 1520. 1470. 1816.  518.  784.   10. 2110. 2050. 4130.
#  1008. 2330. 2030.  516.  704. 2580.  915.  172. 1510.  602. 2550. 1610.
#  1284. 1281. 2170. 1798. 2240. 2070. 1930. 1880. 2020.  508.  295. 2360.
#  2720. 2160.  435.  225. 2220. 1860. 1840. 2590. 2130. 2490.  862. 3000.
#  2310. 2150.  556. 1852.  475. 1548. 1960.  235. 2610.  875. 1024. 2190.
#   415.  792.  768. 1248. 1275.   20. 2850. 1525. 2120. 1913. 2250.   65.
#  1770. 1750. 2570. 2500.  588.  266. 2350. 1481.  274.  248.  935. 1245.
#  2196.  243. 2810.   nan  906. 1920. 2180.]
# dtype: float64

# %%
# We can see, that there's a huge spike at 0 and a long thin tail towards 2000 and above
# We can change the values to 0 or 1. 0 for no basement and 1 for basement present

df.loc[df["basement"].isnull(), "basement"]=0

# %%
df["basement"].isnull().sum()
# Out:
# np.int64(0)

# %%
for index, item in enumerate(df["basement"]):
    if item==0:
        df.loc[index, "basement"]=0
    else:
        df.loc[index, "basement"]=1

# %%
col_info_check(df, "basement", 1)
# Out:
# Missing value count: 0
# Unique values: [1. 0.]
# dtype: float64

# %%
plt.title("Countplot for 'basement'")
sns.countplot(df, x="basement")
plt.show()

# %%
col_info_check(df, "yr_built")
# Out:
# Missing value count: 1
# Unique values: [1966 1948 2009 1924 1994 2005 1978 1983 2012 1912 1990 1967 1919 1908
#  1950 2000 2013 1943 1922 1977 2004 1935 1964 1945 1987 2008 1940 2003
#  1988 1985 1998 1995 1946 1984 1958 1963 1942 2014 1971 1936 1954 1923
#  2002 1972 2007 1930 1962 1999 1953 1965 2010 1997 2006 1979 1996 1992
#  1968 1980 1981 1969 2001 1929 1952 1916 1976 1974 1920 1931 1975 1960
#  1900 '$' 1986 1989 1906 1955 1956 1915 1941 1993 2011 1925 1947 1991 1926
#  1927 1951 1961 1932 1917 1928 1959 1921 1911 1949 1982 1913 1957 1914
#  1938 1973 1937 1944 1970 1901 1907 1939 1918 1934 1904 2015 1909 1910
#  1905 1902 1933 1903 nan]
# dtype: object

# %%
faulty_idx=[index for index, item in enumerate(df["yr_built"]) if item=="$"]

for i in faulty_idx:
    df.loc[i, "yr_built"]=np.nan

# %%
df["yr_built"].isnull().sum()
# Out:
# np.int64(15)

# %%
df["yr_built"].median()
# Out:
# np.float64(1975.0)

# %%
df.groupby("condition")["yr_built"].median()
# Out:
# condition
# 1    1928.0
# 2    1950.0
# 3    1988.0
# 4    1962.0
# 5    1950.0
# $    1978.5
# Name: yr_built, dtype: object

# %%
missing_idx=[index for index, item in enumerate(df["yr_built"].isnull()) if item==True]

# %%
pd.DataFrame({
    "condition":df["condition"][missing_idx],
    "yr_built":df["yr_built"][missing_idx]
})
# Out:
#       condition yr_built
# 131           3      NaN
# 1841          4      NaN
# 1906          3      NaN
# 2407          3      NaN
# 2974          3      NaN
# 4529          3      NaN
# 5351          3      NaN
# 8205          3      NaN
# 13562         5      NaN
# 13581         3      NaN
# 14044         3      NaN
# 14955         3      NaN
# 15749         4      NaN
# 19204         4      NaN
# 21226       NaN      NaN

# %%
for i in missing_idx:
    cond=df.loc[i, "condition"]
    if pd.notna(cond):
        df.loc[i , "yr_built"]=df.groupby("condition")["yr_built"].median()[df["condition"][i]]
    else:
        df.loc[i, "yr_built"]=df["yr_built"].median()

# %%
pd.DataFrame({
    "condition":df["condition"][missing_idx],
    "yr_built":df["yr_built"][missing_idx]
})
# Out:
#       condition yr_built
# 131           3   1988.0
# 1841          4   1962.0
# 1906          3   1988.0
# 2407          3   1988.0
# 2974          3   1988.0
# 4529          3   1988.0
# 5351          3   1988.0
# 8205          3   1988.0
# 13562         5   1950.0
# 13581         3   1988.0
# 14044         3   1988.0
# 14955         3   1988.0
# 15749         4   1962.0
# 19204         4   1962.0
# 21226       NaN   1975.0

# %%
missing_cols=df[[col for col in df.columns if df[col].isnull().sum()>0]].columns.values

# %%
missing_cols
# Out:
# array(['living_measure', 'lot_measure', 'coast', 'sight', 'condition',
#        'quality', 'living_measure15', 'lot_measure15', 'furnished'],
#       dtype=object)

# %%
# condition

col_info_check(df, "condition")
# Out:
# Missing value count: 57
# Unique values: [3 4 5 2 nan 1 '$']
# dtype: object

# %%
faulty_idx=[index for index, item in enumerate(df["condition"]) if item=="$"]

# %%
df.loc[faulty_idx, "condition"]=np.nan

# %%
col_info_check(df, "condition")
# Out:
# Missing value count: 85
# Unique values: [3 4 5 2 nan 1]
# dtype: object

# %%
missing_idx=[index for index, item in enumerate(df["condition"].isnull()) if item == True]

# %%
len(missing_idx)
# Out:
# 85

# %%
df.groupby("yr_built")["condition"].median()
# Out:
# yr_built
# 1900    3.0
# 1901    4.0
# 1902    3.0
# 1903    3.0
# 1904    4.0
#        ...
# 2011    3.0
# 2012    3.0
# 2013    3.0
# 2014    3.0
# 2015    3.0
# Name: condition, Length: 116, dtype: object

# %%
df["yr_built"]=df["yr_built"].astype(int)

# %%
for i in missing_idx:
    df.loc[i, "condition"]=df.groupby("yr_built")["condition"].median()[df["yr_built"][i]]

# %%
df["condition"]=df["condition"].astype("int")

# %%
# quality

col_info_check(df, "quality", 1)
# Out:
# Missing value count: 1
# Unique values: [ 8.  6.  7. 10.  9.  5. 11. 13.  4. 12.  1.  3. nan]
# dtype: float64

# %%
# Imputing missing values with median

df.loc[df["quality"].isnull(), "quality"]=df["quality"].median()

# %%
col_info_check(df, "quality")
# Out:
# Missing value count: 0
# Unique values: [ 8.  6.  7. 10.  9.  5. 11. 13.  4. 12.  1.  3.]
# dtype: float64

# %%
missing_cols
# Out:
# array(['living_measure', 'lot_measure', 'coast', 'sight', 'condition',
#        'quality', 'living_measure15', 'lot_measure15', 'furnished'],
#       dtype=object)

# %%
# furnished

col_info_check(df, "furnished",1)
# Out:
# Missing value count: 29
# Unique values: [ 0.  1. nan]
# dtype: float64

# %%
df['furnished'].value_counts(dropna=False)
# Out:
# furnished
# 0.0    17338
# 1.0     4246
# NaN       29
# Name: count, dtype: int64

# %%
# We'll impute it with mode

df.loc[df["furnished"].isnull(), "furnished"]=df["furnished"].mode().values[0]

# %%
missing_cols
# Out:
# array(['living_measure', 'lot_measure', 'coast', 'sight', 'condition',
#        'quality', 'living_measure15', 'lot_measure15', 'furnished'],
#       dtype=object)

# %%
# living_measure 15

col_info_check(df, "living_measure15")
# Out:
# Missing value count: 166
# Unique values: [2020. 1660. 2620. 2030. 1120. 1610. 1170. 2800. 1850. 1460. 2380. 1880.
#  2440. 1390. 1060. 1280. 1540. 1200. 3050. 1410. 2300. 1440. 1710. 2850.
#  1860. 1830. 1550. 2490. 3330. 1350. 2040. 3100. 1790. 2420. 3000. 1870.
#  1730. 1708. 1670. 1510. 1480. 2820. 1090. 1160. 1220. 2710. 1240. 1320.
#  2120. 1500. 1450. 2400. 2050. 1380. 2070. 1820. 1620. 1268. 2260. 3110.
#  1890. 1260. 3380. 1680. 2502. 1340. 1800. 1180. 2650. 2450. 3730. 2110.
#  2990. 3920. 2330. 2060. 2520. 1330. 1780. 2150. 2790. 2080. 1650. 2530.
#  1760. 2900.  870. 1770. 2190. 1270. 3140. 1140. 1720. 2214. 3340. 2540.
#  3400.   nan 2610. 1400. 3130. 1530. 1690. 2580. 1990. 3390. 3800. 2140.
#   910. 1560. 1150. 4110. 2510. 1050. 3360. 1490. 3010. 2130. 3450. 2740.
#  2200. 2100. 2360. 1580. 3630. 1100. 1020. 1930. 3270. 2310. 1250. 4210.
#  2170. 2220. 3420. 1940. 1570. 2460.  980. 1810. 2270. 1840. 1470.  920.
#  1630.  840. 1520. 1590. 1740. 1300. 1010. 1080. 2340. 2430. 3070. 1230.
#  2350. 3160. 1700. 1980. 1900. 1640. 1420. 2280. 2000. 2250. 1600. 2500.
#  3290. 2640. 1920. 2700. 1430. 2720. 2320. 1110.  990. 2290. 2410. 1370.
#  2240. 2180. 3350. 3550. 3170. 2010. 2415. 1130. 2641. 2840. 2750. 3020.
#  2830. 1290. 3515. 2409. 2910. 1910. 3210. 3250. 5070. 1970. 3470. 2230.
#  3850. 1960. 1326. 3880. 1750.  810. 2168. 3240. 1190. 1310. 1210. 2880.
#  2760. 2550. 1070. 3260. 2390. 2090. 2870. 3180. 1352. 3320.  900. 2770.
#  2630. 1950. 3150. 2940. 2950. 3570. 2160. 2810. 2980. 2780. 2600. 3840.
#  3200. 3890. 2210. 1360. 3540. 2370. 3640. 1000. 3960.  930. 2475. 3590.
#  2256. 2660. 1030. 2930. 2730. 3780. 3370. 4010. 5030. 2570. 2560. 3430.
#  3830. 4020. 4590. 2955.  850. 3670. 4800.  940. 1536. 1365. 1217. 3310.
#  2890. 4920.  750. 2083. 3950. 3650. 3230. 3740. 4913. 4190. 4600. 2590.
#  3900. 2470. 3940. 3510. 1979. 2860. 5600. 2960. 1468. 1442.  960. 3480.
#  3220. 3280. 3190. 1040. 3040. 2155. 3810. 3990. 3625.  970. 1975. 2653.
#  2970. 3460. 3860. 3720. 2669.  880. 3078. 1466.  950. 2396. 1576. 2680.
#  2848. 2480. 3530. 1377. 2234. 2255. 1307. 3030. 4362. 3060. 3090. 3300.
#  3680. 3490. 2670. 1941. 5380. 3610. 2336. 2258. 2920. 3440. 3560. 1664.
#  3770. 2527. 1792. 4050. 2690. 3870. 3620. 4440. 4240. 1746.  860. 3080.
#  4390. 2474. 5790. 4040. 4100. 2246. 4660. 3600. 4090. 4130. 4470. 3930.
#  1414.  720. 2054. 3500. 1654. 2516. 1691. 2077. 1678. 4670. 3568. 1369.
#  2648. 1445. 4480. 4420. 4700. 2875. 4300.  952. 2434. 3710. 2009.  740.
#  4560. 2755. 2665. 2125.  890. 2238. 1398. 2547. 2037. 4740. 2688. 2619.
#  1763. 5080. 1443.  460. 2358. 1494. 4280. 4940. 4220. 3910. 2667. 2165.
#  3056. 1571. 3790. 4170. 3494. 1961. 4080. 3120. 2004. 1677. 4042. 1525.
#  1919. 2056. 4760. 4650. 1765. 3410. 2439. 3750. 1137.  780. 4000. 2095.
#  1528. 1404. 2704. 4320. 3191. 1862. 2297. 1346. 4290. 1884. 2765. 2166.
#  1358. 1584. 2738. 1277. 3674. 2597. 3980. 2615. 1088. 1304. 3690.  710.
#  4830. 2028. 1364. 3660. 2496. 2605. 1439. 1805. 4030. 4730. 3970. 3087.
#  1131. 1714.  830. 3112. 4630.  800. 1408. 4070. 1492. 1448. 1509. 1616.
#  1092. 2912. 1459. 2517.  998. 4340.  820.  760. 2616. 2683. 2305. 2876.
#  4640. 3557. 1798. 3820. 4400. 2879. 2344. 2419. 3520. 2029. 1768. 1188.
#  2242. 1981. 1934. 1132. 5610. 4230. 2052. 1518. 2049. 2005. 2724. 1336.
#  1813. 4950. 2583. 2901. 1544. 2315. 3700. 3760. 2363. 1638. 1232. 1716.
#  4770. 2598. 1658. 4930. 6210. 4180. 4310. 4620. 4850. 3639. 4690. 1078.
#  2575. 4160. 4250. 4060. 4410. 4570. 2555. 4540. 2189. 3580. 2873. 3715.
#  4495. 2844. 4530. 1767. 1356. 3543. 2996. 2488. 4443. 2014. 1168. 2634.
#  4140. 1138. 1175. 4510. 1894. 2967. 2112. 4200. 4260. 1309. 2513. 5340.
#  2478. 2437. 2144. 2451. 2927. 2236. 1458. 2725. 2106. 2389. 1076. 1943.
#  2175. 2279. 3721. 1425.  690. 1399. 1264. 2533. 2027. 2673. 1415. 3836.
#  2406. 3618. 2019. 1564. 5220. 1495. 1834. 2495. 2961. 4330. 2578. 2381.
#  3045. 4750. 3038. 3008. 1554. 1256. 4350. 1321.  399. 2566.  806. 1357.
#  3413. 1484. 2075. 2221. 3402.  790. 1572. 2403. 1914. 1757. 2424. 1285.
#  2647. 2142. 5170. 1481. 2586. 1608. 2405. 2815. 1802. 2015. 1427. 5200.
#  2554. 1156. 2767. 3736. 1381. 2622. 2849. 2981. 1949. 2303. 2216. 2425.
#  3425. 2002. 3159. 2099. 1855. 1125.  620. 2091.  700. 1566. 2323. 1728.
#  1516. 4610. 3726. 2156. 3193. 1303. 2412. 4780. 2822. 4900. 1128. 2594.
#  2136. 1639. 4120. 1921. 4550. 2793. 2253. 2333. 2458. 1984. 2728. 2456.
#  1537. 2092. 1216. 1876. 2154. 2518. 4890. 1056. 1302. 1696. 1522. 4270.
#  5110. 4520.  770. 4680. 1665. 3236. 1162. 1569. 2316. 2798. 1098. 5330.
#  2198. 2273. 2304. 1084. 2604. 1228. 1886. 1847. 1282. 2109. 5500. 2697.
#  1955. 2441. 1745. 2354. 2574. 4460. 2197. 3335. 1463. 6110. 2384. 1815.
#  2076. 2114. 4150. 4370. 1502.  828. 2326. 2011. 1811. 2382. 4490.  670.
#  1546. 1429. 1405. 2612. 5000. 1295. 1786.]
# dtype: float64

# %%
df.loc[df["living_measure15"].isnull(), "living_measure15"]=df["living_measure15"].median()

# %%
# lot_measure15

col_info_check(df, "lot_measure15", 50_000)
# Out:
# Missing value count: 29
# Unique values: [ 8660.  4100.  2433. ... 11491.  2853.  7604.]
# dtype: float64

# %%
df.loc[df["lot_measure15"].isnull(), "lot_measure15"]=df["lot_measure15"].median()

# %%
summary(df)
# Out:
#             col_name    dtype  missing  percentage of missing  unique  \
# 0           dayhours   object        0               0.000000     372
# 1              price    int64        0               0.000000    3625
# 2           room_bed  float64        0               0.000000      13
# 3          room_bath  float64        0               0.000000       9
# 4     living_measure  float64       17               0.078656    1039
# 5        lot_measure  float64       42               0.194327    9766
# 6               ceil  float64        0               0.000000       4
# 7              coast   object        1               0.004627       4
# 8              sight  float64       57               0.263730       6
# 9          condition    int64        0               0.000000       5
# 10           quality  float64        0               0.000000      12
# 11      ceil_measure  float64        0               0.000000     946
# 12          basement  float64        0               0.000000       2
# 13          yr_built    int64        0               0.000000     116
# 14      yr_renovated    int64        0               0.000000      70
# 15           zipcode    int64        0               0.000000      70
# 16               lat  float64        0               0.000000    5034
# 17              long   object        0               0.000000     753
# 18  living_measure15  float64        0               0.000000     774
# 19     lot_measure15  float64        0               0.000000    8682
# 20         furnished  float64        0               0.000000       2
# 21        total_area  float64        0               0.000000   11163
#
#                                      example_uniq_val
# 0   [20150427T000000, 20150317T000000, 20140820T00...
# 1                            [600000, 190000, 735000]
# 2                                     [4.0, 2.0, 3.0]
# 3                                     [2.0, 1.0, 3.0]
# 4                             [3050.0, 670.0, 3040.0]
# 5                            [9440.0, 3101.0, 2415.0]
# 6                                     [1.0, 2.0, 3.0]
# 7                                           [0, 1, $]
# 8                                     [0.0, 4.0, 2.0]
# 9                                           [3, 4, 5]
# 10                                    [8.0, 6.0, 7.0]
# 11                            [1800.0, 670.0, 3040.0]
# 12                                         [1.0, 0.0]
# 13                                 [1966, 1948, 2009]
# 14                                    [0, 1993, 2014]
# 15                              [98034, 98118, 98002]
# 16                        [47.7228, 47.5546, 47.5188]
# 17                     [-122.183, -122.274, -122.256]
# 18                           [2020.0, 1660.0, 2620.0]
# 19                           [8660.0, 4100.0, 2433.0]
# 20                                         [0.0, 1.0]
# 21                          [12490.0, 3771.0, 5455.0]

# %%
# sight

col_info_check(df, "sight",1)
# Out:
# Missing value count: 57
# Unique values: [ 0.  4.  2.  3.  1. nan]
# dtype: float64

# %%
df.loc[df["sight"].isnull(), "sight"]=df["sight"].mode().values[0]

# %%
summary(df)
# Out:
#             col_name    dtype  missing  percentage of missing  unique  \
# 0           dayhours   object        0               0.000000     372
# 1              price    int64        0               0.000000    3625
# 2           room_bed  float64        0               0.000000      13
# 3          room_bath  float64        0               0.000000       9
# 4     living_measure  float64       17               0.078656    1039
# 5        lot_measure  float64       42               0.194327    9766
# 6               ceil  float64        0               0.000000       4
# 7              coast   object        1               0.004627       4
# 8              sight  float64        0               0.000000       5
# 9          condition    int64        0               0.000000       5
# 10           quality  float64        0               0.000000      12
# 11      ceil_measure  float64        0               0.000000     946
# 12          basement  float64        0               0.000000       2
# 13          yr_built    int64        0               0.000000     116
# 14      yr_renovated    int64        0               0.000000      70
# 15           zipcode    int64        0               0.000000      70
# 16               lat  float64        0               0.000000    5034
# 17              long   object        0               0.000000     753
# 18  living_measure15  float64        0               0.000000     774
# 19     lot_measure15  float64        0               0.000000    8682
# 20         furnished  float64        0               0.000000       2
# 21        total_area  float64        0               0.000000   11163
#
#                                      example_uniq_val
# 0   [20150427T000000, 20150317T000000, 20140820T00...
# 1                            [600000, 190000, 735000]
# 2                                     [4.0, 2.0, 3.0]
# 3                                     [2.0, 1.0, 3.0]
# 4                             [3050.0, 670.0, 3040.0]
# 5                            [9440.0, 3101.0, 2415.0]
# 6                                     [1.0, 2.0, 3.0]
# 7                                           [0, 1, $]
# 8                                     [0.0, 4.0, 2.0]
# 9                                           [3, 4, 5]
# 10                                    [8.0, 6.0, 7.0]
# 11                            [1800.0, 670.0, 3040.0]
# 12                                         [1.0, 0.0]
# 13                                 [1966, 1948, 2009]
# 14                                    [0, 1993, 2014]
# 15                              [98034, 98118, 98002]
# 16                        [47.7228, 47.5546, 47.5188]
# 17                     [-122.183, -122.274, -122.256]
# 18                           [2020.0, 1660.0, 2620.0]
# 19                           [8660.0, 4100.0, 2433.0]
# 20                                         [0.0, 1.0]
# 21                          [12490.0, 3771.0, 5455.0]

# %%
# living_measure

col_info_check(df, "living_measure")
# Out:
# Missing value count: 17
# Unique values: [3050.  670. 3040. ... 1405. 1295. 2253.]
# dtype: float64

# %%
missing_idx=[index for index, item in enumerate(df["living_measure"].isnull()) if item==True]

# %%
len(missing_idx)
# Out:
# 17

# %%
for i in missing_idx:
    lot_measure=pd.notna(df["lot_measure"][i])
    if lot_measure:
        df.loc[i, "living_measure"]=df.loc[i, "total_area"]-df.loc[i, "lot_measure"]

# %%
col_info_check(df, "living_measure")
# Out:
# Missing value count: 0
# Unique values: [3050.  670. 3040. ... 1405. 1295. 2253.]
# dtype: float64

# %%
# lot_measure

missing_idx=[index for index, item in enumerate(df["lot_measure"].isnull()) if item==True]

# %%
len(missing_idx)
# Out:
# 42

# %%
for i in missing_idx:
    df.loc[i, "lot_measure"]=df.loc[i, "total_area"]-df.loc[i, "living_measure"]

# %%
summary(df)
# Out:
#             col_name    dtype  missing  percentage of missing  unique  \
# 0           dayhours   object        0               0.000000     372
# 1              price    int64        0               0.000000    3625
# 2           room_bed  float64        0               0.000000      13
# 3          room_bath  float64        0               0.000000       9
# 4     living_measure  float64        0               0.000000    1038
# 5        lot_measure  float64        0               0.000000    9782
# 6               ceil  float64        0               0.000000       4
# 7              coast   object        1               0.004627       4
# 8              sight  float64        0               0.000000       5
# 9          condition    int64        0               0.000000       5
# 10           quality  float64        0               0.000000      12
# 11      ceil_measure  float64        0               0.000000     946
# 12          basement  float64        0               0.000000       2
# 13          yr_built    int64        0               0.000000     116
# 14      yr_renovated    int64        0               0.000000      70
# 15           zipcode    int64        0               0.000000      70
# 16               lat  float64        0               0.000000    5034
# 17              long   object        0               0.000000     753
# 18  living_measure15  float64        0               0.000000     774
# 19     lot_measure15  float64        0               0.000000    8682
# 20         furnished  float64        0               0.000000       2
# 21        total_area  float64        0               0.000000   11163
#
#                                      example_uniq_val
# 0   [20150427T000000, 20150317T000000, 20140820T00...
# 1                            [600000, 190000, 735000]
# 2                                     [4.0, 2.0, 3.0]
# 3                                     [2.0, 1.0, 3.0]
# 4                             [3050.0, 670.0, 3040.0]
# 5                            [9440.0, 3101.0, 2415.0]
# 6                                     [1.0, 2.0, 3.0]
# 7                                           [0, 1, $]
# 8                                     [0.0, 4.0, 2.0]
# 9                                           [3, 4, 5]
# 10                                    [8.0, 6.0, 7.0]
# 11                            [1800.0, 670.0, 3040.0]
# 12                                         [1.0, 0.0]
# 13                                 [1966, 1948, 2009]
# 14                                    [0, 1993, 2014]
# 15                              [98034, 98118, 98002]
# 16                        [47.7228, 47.5546, 47.5188]
# 17                     [-122.183, -122.274, -122.256]
# 18                           [2020.0, 1660.0, 2620.0]
# 19                           [8660.0, 4100.0, 2433.0]
# 20                                         [0.0, 1.0]
# 21                          [12490.0, 3771.0, 5455.0]

# %%
# coast

faulty_idx=[index for index, item in enumerate(df["coast"]) if item == "$"]

# %%
df.loc[faulty_idx, "coast"]=np.nan

# %%
df["coast"]=df["coast"].astype("float")

# %%
col_info_check(df, "coast",1)
# Out:
# Missing value count: 31
# Unique values: [ 0.  1. nan]
# dtype: float64

# %%
df.loc[df["coast"].isnull(), "coast"]=df["coast"].mode().values[0]

# %%
summary(df)
# Out:
#             col_name    dtype  missing  percentage of missing  unique  \
# 0           dayhours   object        0                    0.0     372
# 1              price    int64        0                    0.0    3625
# 2           room_bed  float64        0                    0.0      13
# 3          room_bath  float64        0                    0.0       9
# 4     living_measure  float64        0                    0.0    1038
# 5        lot_measure  float64        0                    0.0    9782
# 6               ceil  float64        0                    0.0       4
# 7              coast  float64        0                    0.0       2
# 8              sight  float64        0                    0.0       5
# 9          condition    int64        0                    0.0       5
# 10           quality  float64        0                    0.0      12
# 11      ceil_measure  float64        0                    0.0     946
# 12          basement  float64        0                    0.0       2
# 13          yr_built    int64        0                    0.0     116
# 14      yr_renovated    int64        0                    0.0      70
# 15           zipcode    int64        0                    0.0      70
# 16               lat  float64        0                    0.0    5034
# 17              long   object        0                    0.0     753
# 18  living_measure15  float64        0                    0.0     774
# 19     lot_measure15  float64        0                    0.0    8682
# 20         furnished  float64        0                    0.0       2
# 21        total_area  float64        0                    0.0   11163
#
#                                      example_uniq_val
# 0   [20150427T000000, 20150317T000000, 20140820T00...
# 1                            [600000, 190000, 735000]
# 2                                     [4.0, 2.0, 3.0]
# 3                                     [2.0, 1.0, 3.0]
# 4                             [3050.0, 670.0, 3040.0]
# 5                            [9440.0, 3101.0, 2415.0]
# 6                                     [1.0, 2.0, 3.0]
# 7                                          [0.0, 1.0]
# 8                                     [0.0, 4.0, 2.0]
# 9                                           [3, 4, 5]
# 10                                    [8.0, 6.0, 7.0]
# 11                            [1800.0, 670.0, 3040.0]
# 12                                         [1.0, 0.0]
# 13                                 [1966, 1948, 2009]
# 14                                    [0, 1993, 2014]
# 15                              [98034, 98118, 98002]
# 16                        [47.7228, 47.5546, 47.5188]
# 17                     [-122.183, -122.274, -122.256]
# 18                           [2020.0, 1660.0, 2620.0]
# 19                           [8660.0, 4100.0, 2433.0]
# 20                                         [0.0, 1.0]
# 21                          [12490.0, 3771.0, 5455.0]

# %% [markdown]
# <h3><i><span style="color:cyan">Feature Selection</span></i></h3>

# %%
# Lets drop, lat and long first

df=df.drop(["lat","long"],axis=1)

# %%
summary(df)
# Out:
#             col_name    dtype  missing  percentage of missing  unique  \
# 0           dayhours   object        0                    0.0     372
# 1              price    int64        0                    0.0    3625
# 2           room_bed  float64        0                    0.0      13
# 3          room_bath  float64        0                    0.0       9
# 4     living_measure  float64        0                    0.0    1038
# 5        lot_measure  float64        0                    0.0    9782
# 6               ceil  float64        0                    0.0       4
# 7              coast  float64        0                    0.0       2
# 8              sight  float64        0                    0.0       5
# 9          condition    int64        0                    0.0       5
# 10           quality  float64        0                    0.0      12
# 11      ceil_measure  float64        0                    0.0     946
# 12          basement  float64        0                    0.0       2
# 13          yr_built    int64        0                    0.0     116
# 14      yr_renovated    int64        0                    0.0      70
# 15           zipcode    int64        0                    0.0      70
# 16  living_measure15  float64        0                    0.0     774
# 17     lot_measure15  float64        0                    0.0    8682
# 18         furnished  float64        0                    0.0       2
# 19        total_area  float64        0                    0.0   11163
#
#                                      example_uniq_val
# 0   [20150427T000000, 20150317T000000, 20140820T00...
# 1                            [600000, 190000, 735000]
# 2                                     [4.0, 2.0, 3.0]
# 3                                     [2.0, 1.0, 3.0]
# 4                             [3050.0, 670.0, 3040.0]
# 5                            [9440.0, 3101.0, 2415.0]
# 6                                     [1.0, 2.0, 3.0]
# 7                                          [0.0, 1.0]
# 8                                     [0.0, 4.0, 2.0]
# 9                                           [3, 4, 5]
# 10                                    [8.0, 6.0, 7.0]
# 11                            [1800.0, 670.0, 3040.0]
# 12                                         [1.0, 0.0]
# 13                                 [1966, 1948, 2009]
# 14                                    [0, 1993, 2014]
# 15                              [98034, 98118, 98002]
# 16                           [2020.0, 1660.0, 2620.0]
# 17                           [8660.0, 4100.0, 2433.0]
# 18                                         [0.0, 1.0]
# 19                          [12490.0, 3771.0, 5455.0]

# %%
# dayhours only has date object and no time, so we won't be deriving any meaningful insights, so let's drop it

df=df.drop("dayhours", axis=1)

# %%
# Let's make a new age column

current_yr=2025

df["age"]=current_yr-df["yr_built"]

# %%
summary(df)
# Out:
#             col_name    dtype  missing  percentage of missing  unique  \
# 0              price    int64        0                    0.0    3625
# 1           room_bed  float64        0                    0.0      13
# 2          room_bath  float64        0                    0.0       9
# 3     living_measure  float64        0                    0.0    1038
# 4        lot_measure  float64        0                    0.0    9782
# 5               ceil  float64        0                    0.0       4
# 6              coast  float64        0                    0.0       2
# 7              sight  float64        0                    0.0       5
# 8          condition    int64        0                    0.0       5
# 9            quality  float64        0                    0.0      12
# 10      ceil_measure  float64        0                    0.0     946
# 11          basement  float64        0                    0.0       2
# 12          yr_built    int64        0                    0.0     116
# 13      yr_renovated    int64        0                    0.0      70
# 14           zipcode    int64        0                    0.0      70
# 15  living_measure15  float64        0                    0.0     774
# 16     lot_measure15  float64        0                    0.0    8682
# 17         furnished  float64        0                    0.0       2
# 18        total_area  float64        0                    0.0   11163
# 19               age    int64        0                    0.0     116
#
#              example_uniq_val
# 0    [600000, 190000, 735000]
# 1             [4.0, 2.0, 3.0]
# 2             [2.0, 1.0, 3.0]
# 3     [3050.0, 670.0, 3040.0]
# 4    [9440.0, 3101.0, 2415.0]
# 5             [1.0, 2.0, 3.0]
# 6                  [0.0, 1.0]
# 7             [0.0, 4.0, 2.0]
# 8                   [3, 4, 5]
# 9             [8.0, 6.0, 7.0]
# 10    [1800.0, 670.0, 3040.0]
# 11                 [1.0, 0.0]
# 12         [1966, 1948, 2009]
# 13            [0, 1993, 2014]
# 14      [98034, 98118, 98002]
# 15   [2020.0, 1660.0, 2620.0]
# 16   [8660.0, 4100.0, 2433.0]
# 17                 [0.0, 1.0]
# 18  [12490.0, 3771.0, 5455.0]
# 19               [59, 77, 16]

# %%
# correlation between yr_built and  age

df[["age","yr_built"]].corr()
# Out:
#           age  yr_built
# age       1.0      -1.0
# yr_built -1.0       1.0

# %%
# It has a perfectly inverse correlation, let's drop the yr_built column as well

df=df.drop("yr_built", axis=1)

# %%
summary(df)
# Out:
#             col_name    dtype  missing  percentage of missing  unique  \
# 0              price    int64        0                    0.0    3625
# 1           room_bed  float64        0                    0.0      13
# 2          room_bath  float64        0                    0.0       9
# 3     living_measure  float64        0                    0.0    1038
# 4        lot_measure  float64        0                    0.0    9782
# 5               ceil  float64        0                    0.0       4
# 6              coast  float64        0                    0.0       2
# 7              sight  float64        0                    0.0       5
# 8          condition    int64        0                    0.0       5
# 9            quality  float64        0                    0.0      12
# 10      ceil_measure  float64        0                    0.0     946
# 11          basement  float64        0                    0.0       2
# 12      yr_renovated    int64        0                    0.0      70
# 13           zipcode    int64        0                    0.0      70
# 14  living_measure15  float64        0                    0.0     774
# 15     lot_measure15  float64        0                    0.0    8682
# 16         furnished  float64        0                    0.0       2
# 17        total_area  float64        0                    0.0   11163
# 18               age    int64        0                    0.0     116
#
#              example_uniq_val
# 0    [600000, 190000, 735000]
# 1             [4.0, 2.0, 3.0]
# 2             [2.0, 1.0, 3.0]
# 3     [3050.0, 670.0, 3040.0]
# 4    [9440.0, 3101.0, 2415.0]
# 5             [1.0, 2.0, 3.0]
# 6                  [0.0, 1.0]
# 7             [0.0, 4.0, 2.0]
# 8                   [3, 4, 5]
# 9             [8.0, 6.0, 7.0]
# 10    [1800.0, 670.0, 3040.0]
# 11                 [1.0, 0.0]
# 12            [0, 1993, 2014]
# 13      [98034, 98118, 98002]
# 14   [2020.0, 1660.0, 2620.0]
# 15   [8660.0, 4100.0, 2433.0]
# 16                 [0.0, 1.0]
# 17  [12490.0, 3771.0, 5455.0]
# 18               [59, 77, 16]

# %% [markdown]
# <h3><i><span style="color:cyan">Outlier treatment</span></i></h3>

# %%
def IQR(df:pd.DataFrame, col:str):
    outliers=[]

    q1=df[col].quantile(0.25)
    q3=df[col].quantile(0.75)

    IQR=q3-q1
    
    lower_bound=q1-1.5*IQR
    upper_bound=q3+1.5*IQR

    for i in df[col]:
        if i<lower_bound and i>upper_bound:
            outliers.append(i)
    return outliers

# %%
numeric_cols = [
    'room_bed', 'room_bath', 'living_measure', 'lot_measure', 'ceil',
    'coast', 'sight', 'condition', 'quality', 'ceil_measure',
    'basement', 'living_measure15', 'lot_measure15',
    'furnished', 'total_area', 'age'
]

# %%
for col in numeric_cols:
    print(IQR(df, col))
# Out:
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []

# %%
# We need to check columns for higher correlation

corr=df.corr()

plt.figure(figsize=(20,10))
sns.heatmap(corr, cmap="coolwarm", annot=True)
plt.show()

# %%
correlation=[]

threshold=0.80

for i in corr:
    for j in corr:
        if abs(corr.loc[i,j])>=threshold and i!=j:
            correlation.append((i,j, f"{float(corr.loc[i,j]):.3f}"))

# %%
correlation
# Out:
# [('living_measure', 'ceil_measure', '0.877'),
#  ('lot_measure', 'total_area', '1.000'),
#  ('ceil_measure', 'living_measure', '0.877'),
#  ('total_area', 'lot_measure', '1.000')]

# %%
# Let's remove the highly correlated columns

cols_to_remove=[
    'total_area', 'ceil_measure'
]

df=df.drop(cols_to_remove, axis=1)

# %%
# As we saw, that there are no outliers in the continuous numerical columns. So we can continue with Feature Scaling

cols_to_scale = [
    'living_measure', 'lot_measure',  'basement',
    'living_measure15', 'lot_measure15', 'age'
]

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc=StandardScaler()

# %%
# We'll be making a new dataframe with scaled data

df_scaled=df.copy(deep=True)

# %%
df_scaled[cols_to_scale]=sc.fit_transform(df[cols_to_scale])

# %%
df_scaled.head()
# Out:
#     price  room_bed  room_bath  living_measure  lot_measure  ceil  coast  \
# 0  600000       4.0        2.0        1.056271    -0.136819   1.0    0.0
# 1  190000       2.0        1.0       -1.535137    -0.289862   1.0    0.0
# 2  735000       4.0        3.0        1.045383    -0.306425   2.0    1.0
# 3  257000       3.0        2.0       -0.370092    -0.274894   2.0    0.0
# 4  450000       2.0        1.0       -1.045165    -0.253913   1.0    0.0
#
#    sight  condition  quality  basement  yr_renovated  zipcode  \
# 0    0.0          3      8.0  1.243624             0    98034
# 1    0.0          4      6.0 -0.804102             0    98118
# 2    4.0          3      8.0 -0.804102             0    98118
# 3    0.0          3      8.0 -0.804102             0    98002
# 4    0.0          3      7.0 -0.804102             0    98118
#
#    living_measure15  lot_measure15  furnished       age
# 0          0.049875      -0.150342        0.0  0.170785
# 1         -0.477222      -0.317567        0.0  0.783752
# 2          0.928369      -0.378699        0.0  0.170785
# 3          0.064517      -0.328789        0.0 -1.293524
# 4         -1.267867      -0.280895        0.0  1.601041

# %% [markdown]
# <h3><i><span style="color:cyan">Model Building</span></i></h3>

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from xgboost import XGBRegressor
from sklearn.neighbors import KNeighborsRegressor

# %%
from sklearn.metrics import mean_squared_error, root_mean_squared_error, r2_score, mean_absolute_error

# %%
# let's split the data to training and testing data

from sklearn.model_selection import train_test_split

# %%
# Let's make helper function for telling the model stats

def stats(y_train,y_test , y_pred_train, y_pred_test)->dict[str, int]:
    train_mse=mean_squared_error(y_train, y_pred_train)
    train_rmse=root_mean_squared_error(y_train, y_pred_train)
    train_r_squared=r2_score(y_train, y_pred_train)
    
    test_mse=mean_squared_error(y_test, y_pred_test)
    test_rmse=root_mean_squared_error(y_test, y_pred_test)
    test_r_squared=r2_score(y_test, y_pred_test)

    return {
        "train_mse":train_mse,
        "train_rmse":train_rmse,
        "train_r_squared":train_r_squared,
        "test_mse":test_mse,
        "test_rmse":test_rmse,
        "test_r_squared":test_r_squared
    }

# %%
model_data={
    "LinearRegression":[],
    "DecisionTreeRegressor":[],
    "RandomForestRegressor":[],
    "XGBRegressor":[]
}

# %%
x=df.drop("price",axis=1)
y=df["price"]

x_scaled=df_scaled.drop("price", axis=1)
y_scaled=df_scaled["price"]

# %%
x_train, x_test, y_train, y_test=train_test_split(x,y, test_size=0.3, random_state=42)
x_train_scaled, x_test_scaled, y_train, y_test=train_test_split(x,y, test_size=0.3, random_state=42)

# %%
lr=LinearRegression()

# %%
lr.fit(x_train_scaled,y_train)
# Out:
# LinearRegression()

# %%
y_pred_train_scaled=lr.predict(x_train)
y_pred_test_scaled=lr.predict(x_test)

# %%
y_pred_train_scaled=[f"{i:.3f}" for i in y_pred_train_scaled]
y_pred_test_scaled=[f"{i:.3f}" for i in y_pred_test_scaled]

# %%
lr_stats=stats(y_train, y_test, y_pred_train_scaled, y_pred_test_scaled)

# %%
# Decision Tree Regressor

dt=DecisionTreeRegressor()

# %%
dt.fit(x_train_scaled, y_train)
# Out:
# DecisionTreeRegressor()

# %%
y_pred_train_scaled=dt.predict(x_train_scaled)
y_pred_test_scaled=dt.predict(x_test_scaled)

# %%
dt_stats=stats(y_train, y_test, y_pred_train_scaled, y_pred_test_scaled)

# %%
# Random Forest Regressor

rf=RandomForestRegressor(n_estimators=100, verbose=True, n_jobs=-1)

# %%
rf.fit(x_train, y_train)
# Out:
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed:    4.0s finished
# RandomForestRegressor(n_jobs=-1, verbose=True)

# %%
y_pred_train=rf.predict(x_train)
y_pred_test=rf.predict(x_test)
# Out:
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=4)]: Done 100 out of 100 | elapsed:    0.1s finished
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=4)]: Done 100 out of 100 | elapsed:    0.0s finished

# %%
rf_stats=stats(y_train, y_test, y_pred_train, y_pred_test)

# %%
rf_stats
# Out:
# {'train_mse': 3516403215.706812,
#  'train_rmse': 59299.268256082316,
#  'train_r_squared': 0.9743580839767247,
#  'test_mse': 22628958716.35205,
#  'test_rmse': 150429.24820776063,
#  'test_r_squared': 0.8257009814511233}

# %%
# GradientBoostingRegressor

gbr=GradientBoostingRegressor()

# %%
gbr.fit(x_train, y_train)
# Out:
# GradientBoostingRegressor()

# %%
y_pred_train=gbr.predict(x_train)
y_pred_test=gbr.predict(x_test)

# %%
gbr_stats=stats(y_train, y_test, y_pred_train, y_pred_test)

# %%
# XGBoost

xg=XGBRegressor()

# %%
xg.fit(x_train, y_train, verbose=True)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=None, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=None,
#              n_jobs=None, num_parallel_tree=None, ...)

# %%
y_pred_train=xg.predict(x_train)
y_pred_test=xg.predict(x_test)

# %%
xg_stats=stats(y_train, y_test, y_pred_train, y_pred_test)

# %%
xg_stats
# Out:
# {'train_mse': 4379468800.0,
#  'train_rmse': 66177.5546875,
#  'train_r_squared': 0.968064546585083,
#  'test_mse': 20075249664.0,
#  'test_rmse': 141687.15625,
#  'test_r_squared': 0.845370888710022}

# %%
# KNN

KNN=KNeighborsRegressor(n_neighbors=10,n_jobs=-1)

# %%
KNN.fit(x_train, y_train)
# Out:
# KNeighborsRegressor(n_jobs=-1, n_neighbors=10)

# %%
y_pred_train=KNN.predict(x_train)
y_pred_test=KNN.predict(x_test)

# %%
KNN_stats=stats(y_train, y_test, y_pred_train, y_pred_test)

# %%
KNN_stats
# Out:
# {'train_mse': 58226719950.8661,
#  'train_rmse': 241302.13416144106,
#  'train_r_squared': 0.57540572803999,
#  'test_mse': 62864210879.9486,
#  'test_rmse': 250727.36364415553,
#  'test_r_squared': 0.5157899046275234}

# %%
models=[lr_stats, dt_stats, rf_stats, gbr_stats, xg_stats, KNN_stats]

# %%
# Dataframe for different model interpretations

pd.DataFrame({
    "train_mse":[f"{i["train_mse"]:.3f}" for i in models],
    "test_mse":[f"{i["test_mse"]:.3f}" for i in models],
    "train_rmse":[f"{i["train_rmse"]:.3f}" for i in models],
    "test_rmse":[f"{i["test_rmse"]:.3f}" for i in models],
    "train_r_squared":[f"{i["train_r_squared"]:.3f}" for i in models],
    "test_r_squared":[f"{i["test_r_squared"]:.3f}" for i in models]
},index=["LinearRegression","DecisionTreeRegressor","RandomForestRegressor","GradientBoostingRegressor","XGBoost" ,"KNN"])
# Out:
#                                  train_mse         test_mse  train_rmse  \
# LinearRegression           47239249867.058  44612317311.820  217345.922
# DecisionTreeRegressor         98341609.826  38856625448.064    9916.734
# RandomForestRegressor       3516403215.707  22628958716.352   59299.268
# GradientBoostingRegressor  20712350108.559  23761769534.942  143917.859
# XGBoost                     4379468800.000  20075249664.000   66177.555
# KNN                        58226719950.866  62864210879.949  241302.134
#
#                             test_rmse train_r_squared test_r_squared
# LinearRegression           211216.281           0.656          0.656
# DecisionTreeRegressor      197120.840           0.999          0.701
# RandomForestRegressor      150429.248           0.974          0.826
# GradientBoostingRegressor  154148.531           0.849          0.817
# XGBoost                    141687.156           0.968          0.845
# KNN                        250727.364           0.575          0.516
